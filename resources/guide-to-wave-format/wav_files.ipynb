# %% [markdown]
# # The WAVE Audio File Format in Python
#
#
#
# This sections will cover how to deal with [WAVE format files](https://ccrma.stanford.edu/courses/422-winter-2014/projects/WaveFormat) in python.
#
# There are modules available already in python that can generate `.wav` files from multiple data types. The purpose of this resource is to demonstrate the fundamental principles of creating a `.wav` file entriely from scratch, regardless of the programming langauage used.
#
# This resource aims to provide a guide for an instructor to create a light-weight utility for students which can be deployed easily. This is particularly useful when there is limited internet access or administrative privileges and when the installation of additional software on students computers is not trivial.
#
# This is also resource for the curious student who would like to know a little more about how digital audio files are structured.
#
# The following notebook is written in python using exlusively standard libraries. No additional packages are required. Alongside this article are some examples of how to achieve the same functionality in other programming languages. One of Python's standard modules is the [`wave` module](https://docs.python.org/3/library/wave.html) and an example of how to use it is provided in the section [Using the `wave` Module](#Using-the-wave-Module). The `wave` module section is helpful if you simply require a quick method for audio playback as part of your lesson plan.
# <!-- Much of the same philosophy from the rest of this article is applicable, some components may be a little more opaque when designing a library. -->
#
#
# ## A WAVE Library of One's Own
#
# The act of writing one's own library for creating WAVE format files can be beneficial in several ways. The following are some key advantages of doing so:
#
# - **Reusable**: A custom library can be designed to be simple and easy to understand, making it an excellent tool for students to learn from and modify. At the end of a course, the library can be passed on to students, giving them a valuable resource that they can use to explore and learn about audio programming. The library can serve as a starting point for their own projects, and they can modify it to suit their needs.
#
# - **Agile**: By creating their own library, students have the freedom to make changes as necessary. They are not limited by the constraints of a pre-existing library or framework. If a student needs to add a new feature or modify an existing one as part of their practice, they can do so quickly and easily. This agility is especially important in a creative environment where project requirements can change rapidly.
#
# - **Flexible**: A custom library can be a valuable asset when administrative privileges, internet connections, or other information technology issues get in the way of a well prepared lesson plan. By having a self-contained library that does not rely on external dependencies, you can be confident that the same behaviour will be exhibited across multiple platforms. You can drop the library into any project and it will work without requiring additional setup or configuration.
#
# - **Personal**: Creating your own library is a reflection of one's needs and goals. As an instructor, you may want to adapt the ideas below to create coding challenges or exercises tailored to your own curriculum. As a sound designer or musician, you may want to add functionality specific to your creative workflow or process. The ability to customise a library to fit your needs makes it a powerful tool that can help you achieve your creative goals.

# %% [markdown]
# ## WAVE Format Header
#
# The elegant part of the WAVE file format is that its header is quite simple to understand. It is this header that actually defines a WAVE file — the `.wav` extension is merely a hint to software about what the file contains.
#
# There are 44 bytes of header data to understand. Most of these are fixed values, so there isn’t much to remember.
#
# Below is a table showing the header layout in order. The *Offset* and *Size* columns are given in bytes:
#
# | Endian | Offset | Field Name       | Size |
# | -----: | :----: | ---------------- | :--: |
# |    big |   0    | Chunk ID         |  4   |
# | little |   4    | Chunk Size       |  4   |
# |    big |   8    | Format           |  4   |
# |    big |   12   | Subchunk 1 ID    |  4   |
# | little |   16   | Subchunk 1 Size  |  4   |
# | little |   20   | Audio Format     |  2   |
# | little |   22   | Num Channels     |  2   |
# | little |   24   | Sample Rate      |  4   |
# | little |   28   | Byte Rate        |  4   |
# | little |   32   | Block Align      |  2   |
# | little |   34   | Bits Per Sample  |  2   |
# |    big |   36   | Subchunk 2 ID    |  4   |
# | little |   40   | Subchunk 2 Size  |  4   |
# | little |   44   | PCM Audio Data   |  ?   |
#
# The only field with an unknown size is the PCM audio data, as this depends on both the number of samples and the bit depth.
#
# ### Notes on Terminology
#
# A few notes on terminology before we continue:
#
# - **Pulse Code Modulation (PCM):** The standard format of digital audio typically found in a WAVE file.
# - **Byte depth vs. bit depth:** These refer to fundamentally the same concept. Digital PCM audio resolution is generally expressed as *bit depth* (or *bits per sample*). *Byte depth* is simply bit depth ÷ 8 — that is, bit depth expressed in bytes.
# - **WAVE format vs. wav vs. `.wav`:** These all refer to a file in the WAVE format and are used interchangeably.
# - **Samples vs. frames:** In PCM audio, a *sample* is a single digital amplitude value for one channel. A *frame* is a collection of samples across all channels at a single moment in time. For monophonic audio, “sample” and “frame” are *technically* the same thing, but this guide will maintain the distinction to avoid confusion when working with multiple channels.
# - **Endian:** The order of bytes in a multi-byte number. For example, the number `234` could be described from the "big end" as "2 hundreds, 3 tens, 4 units", or from the "little end" as "4 units, 3 tens, 2 hundreds". The same idea applies to multi-byte data. In practice, this determines the order in which bytes are written when encoding a value. Don’t worry — this will be made explicit when needed.
#
# ### Header Values
#
# Below is a table of the header fields, their types, and the values or calculations required:
#
# |               Data Type | C Type     | Field Name       | Value                                           | Description                                      |
# | ----------------------: | :--------- | ---------------- | :---------------------------------------------- | :----------------------------------------------- |
# |      4 ASCII characters | `char[4]`  | Chunk ID         | `"RIFF"`                                        | The characters `R`, `I`, `F`, `F`                |
# | unsigned 4-byte integer | `uint32_t` | Chunk Size       | `4 + (8 + Subchunk1Size) + (8 + Subchunk2Size)` | Total file size in bytes minus 8 bytes           |
# |      4 ASCII characters | `char[4]`  | Format           | `"WAVE"`                                        | The characters `W`, `A`, `V`, `E`                |
# |      4 ASCII characters | `char[4]`  | Subchunk 1 ID    | `"fmt "`                                        | The characters `f`, `m`, `t`, ` `                |
# | unsigned 4-byte integer | `uint32_t` | Subchunk 1 Size  | `16`                                            | Size of the format subchunk (PCM)                |
# | unsigned 2-byte integer | `uint16_t` | Audio Format     | `1`                                             | `1` for PCM. See appendix on audio formats       |
# | unsigned 2-byte integer | `uint16_t` | Num Channels     | `1`                                             | Number of channels: 1 = mono, 2 = stereo         |
# | unsigned 4-byte integer | `uint32_t` | Sample Rate      | `44100`                                         | Sampling rate in Hz                              |
# | unsigned 4-byte integer | `uint32_t` | Byte Rate        | `SampleRate * NumChannels * BitsPerSample / 8`  | Bytes per second of audio data                   |
# | unsigned 2-byte integer | `uint16_t` | Block Align      | `NumChannels * BitsPerSample / 8`               | Size of one frame in bytes                       |
# | unsigned 2-byte integer | `uint16_t` | Bits Per Sample  | `16`                                            | Number of bits per sample                        |
# |      4 ASCII characters | `char[4]`  | Subchunk 2 ID    | `"data"`                                        | The characters `d`, `a`, `t`, `a`                |
# | unsigned 4-byte integer | `uint32_t` | Subchunk 2 Size  | `NumSamples * NumChannels * BitsPerSample / 8`  | Size of the audio data in bytes (excluding header) |
#
# The audio data type is determined by the `Bits Per Sample` and `Audio Format` fields. For the remainder of this article, we will work exclusively with 16-bit audio.
#
# If you would like to experiment further or set yourself a challenge involving different resolutions, these are the two fields you will need to modify.
#
# #### Header Value Notes
#
# There are some common stumbling blocks worth being aware of, as they can provide useful learning opportunities for students.
#
# - **Subchunk 1 ID:** There is a trailing space character ` ` in the `"fmt "` string that is very easy to miss. In fact, `Chunk ID`, `Format`, `Subchunk 1 ID`, and `Subchunk 2 ID` are all ASCII strings. You can ask students to open a WAVE file in a text editor and see if they can spot them. They may also find other identifiers such as `bext`, which indicates a broadcast extension (BWF) file.
# - **PCM audio data:** PCM audio is typically signed, except for 8-bit (1 byte) data, which is unsigned and centred around `127`.
# - **File size limit:** There is a hard limit on the size of a WAVE file because `Chunk Size` is a 4-byte unsigned integer. This limits the file size to $2^{32}$ bytes (approximately 4.29 Gigabytes).

# %% [markdown]
# ## Creating a WAVE file
#
# So far, we have covered the structure of the WAVE file format, but it remains somewhat abstract until we actually use that information to create a file. This section provides step-by-step instructions for building a WAVE file, along with notes on potential issues you or your students may encounter.
#
# Like any recipe, let’s first assemble our ingredients before we start cooking. From the table above, we can take the field names and convert them into more Pythonic variable names:
#
# | Field Name       | Python variable    |
# | ----------------:| :----------------- |
# | Chunk ID         | `chunk_id`         |
# | Chunk Size       | `chunk_size`       |
# | Format           | `format`           |
# | Subchunk 1 ID    | `sub_chunk_1_id`   |
# | Subchunk 1 Size  | `sub_chunk_1_size` |
# | Audio Format     | `audio_format`     |
# | Num Channels     | `num_channels`     |
# | Sample Rate      | `sample_rate`      |
# | Byte Rate        | `byte_rate`        |
# | Block Align      | `block_align`      |
# | Bits Per Sample  | `bits_per_sample`  |
# | Subchunk 2 ID    | `sub_chunk_2_id`   |
# | Subchunk 2 Size  | `sub_chunk_2_size` |
#
# We already know the values that most of these fields must take, so we can fill in many of them:
#
# | Field Name       | Python variable    | Value                                                 |
# | ---------------: | :----------------- | :---------------------------------------------------- |
# | Chunk ID         | `chunk_id`         | `b"RIFF"`                                             |
# | Chunk Size       | `chunk_size`       | `4 + (8 + sub_chunk_1_size) + (8 + sub_chunk_2_size)` |
# | Format           | `format`           | `b"WAVE"`                                             |
# | Subchunk 1 ID    | `sub_chunk_1_id`   | `b"fmt "`                                             |
# | Subchunk 1 Size  | `sub_chunk_1_size` | `16`                                                  |
# | Audio Format     | `audio_format`     | `1`                                                   |
# | Num Channels     | `num_channels`     | `1`                                                   |
# | Sample Rate      | `sample_rate`      | `44100`                                               |
# | Byte Rate        | `byte_rate`        | `sample_rate * num_channels * bits_per_sample / 8`    |
# | Block Align      | `block_align`      | `num_channels * bits_per_sample / 8`                  |
# | Bits Per Sample  | `bits_per_sample`  | `16`                                                  |
# | Subchunk 2 ID    | `sub_chunk_2_id`   | `b"data"`                                             |
# | Subchunk 2 Size  | `sub_chunk_2_size` | `num_samples * num_channels * bits_per_sample / 8`    |
#
# Which gives us:
#
# ```python
# chunk_id         = b"RIFF"
# chunk_size       = 4 + (8 + sub_chunk_1_size) + (8 + sub_chunk_2_size)
# format           = b"WAVE"
# sub_chunk_1_id   = b"fmt "
# sub_chunk_1_size = 16
# audio_format     = 1
# num_channels     = 1
# sample_rate      = 44100
# byte_rate        = sample_rate * num_channels * bits_per_sample / 8
# block_align      = num_channels * bits_per_sample / 8
# bits_per_sample  = 16
# sub_chunk_2_id   = b"data"
# sub_chunk_2_size = num_samples * num_channels * bits_per_sample / 8
# ```
#
# For the character fields, we must use byte strings, which [requires the prefix `b`](https://docs.python.org/3/reference/lexical_analysis.html#string-and-bytes-literals) e.g. `b"RIFF"`
#
# We now run into the problem of needing the audio data before we can determine its size. We also need to reorder the code above, since some variables are currently used before they are defined.
#
# Let us begin by generating some audio data. We start by importing some functions and variables from the [`math` module](https://docs.python.org/3/library/math.html).
#
# - `sin`: to create a sinusoidal wave
# - `pi`: to step through the phase of a sin wav

# %%
from math import sin, pi

# %% [markdown]
# For the audio we create a 440 Hz sinusoid that is 1 second long at sampling rate 44.1 kHz.

# %%
fs       = 44100.0   # Sampling Rate 
f0       = 440.0     # Fundamental frequency
duration = 1.0       # in seconds

delta    = 2.0 * pi * f0 / fs # how much does the phase change between samples
sine_wave = [sin(delta * i) for i in range(int(duration*fs))]

# %% [markdown]
# The total number of samples is the length of the `sine_wave array`

# %%
num_samples = len(sine_wave)

# %% [markdown]
# Now we can start populating the fields of the WAVE header described in [the table above](#Header-Values).

# %%
chunk_id         = b'RIFF'                                             
format           = b'WAVE'                                              
sub_chunk_1_id   = b'fmt '                                             
sub_chunk_1_size = 16                                                 
audio_format     = 1                                                  
num_channels     = 1                                                  
sample_rate      = 44100                                              
bits_per_sample  = 16                                                 
sub_chunk_2_id   = b'data'                                             
byte_rate        = sample_rate * num_channels * bits_per_sample // 8     
block_align      = num_channels * bits_per_sample // 8                   
sub_chunk_2_size = num_samples * num_channels * bits_per_sample // 8     
chunk_size       = 4 + (8 + sub_chunk_1_size) + (8 + sub_chunk_2_size)

# %% [markdown]
# Note: the [`//` floor division operator]() is used here to ensure the result is an integer.
#
# Even though we have assigned the fields out of order, it is very important that we _write_ them _in order_ as presented in the table above.
#
# Before we start writing, we need a name for our file.

# %%
filename = "a440Hz.wav"

# %% [markdown]
# To write a file in python 3 we can use the `with open(filename,'wb')` construct.
# Since we are not writing text, but rather byte data, we use [`wb` option in `open`](https://docs.python.org/3/library/functions.html#open).
#
# - 'w' as we are _writing_ to the file.
# - 'b' as we want to open a file and write to it in binary mode.
#
# | Character | Meaning                                                         |
# |-----------|-----------------------------------------------------------------|
# | 'r'       | open for reading (default)                                      |
# | 'w'       | open for writing, truncating the file first                     |
# | 'x'       | open for exclusive creation, failing if the file already exists |
# | 'a'       | open for writing, appending to the end of file if it exists     |
# | 'b'       | binary mode                                                     |
# | 't'       | text mode (default)                                             |
# | '+'       | open for updating (reading and writing)                         |

# %%
wav_file =  open(filename, 'wb')

# %% [markdown]
# To write the data in the correct byte order (remember the Endian column from the first table) we can use the [`struct` module](https://docs.python.org/3/library/struct.html). The `struct` module's `pack` and `unpack` allows us to control [what order the data is written](https://docs.python.org/3/library/struct.html#byte-order-size-and-alignment) and [its type](https://docs.python.org/3/library/struct.html#format-characters).

# %%
import struct

# %% [markdown]
# Taking the values from the tables in the `struct` documentation that is most relevant to us:
#
# | Format | Type                      |
# | :----: | ------------------------: |
# | `H`    | unsigned 16-bit integer   |
# | `h`    | signed 16-bit integer     |
# | `I`    | unsigned 32-bit integer   |
# | `s`    | byte string of characters |
#
#
# | Character | Endian   |
# | --------- | -------- |
# | `<`       | `little` |
# | `>`       | `big`    |
#
#
# For example, `chunk_id` is a string with 4 characters and the `struct` format would be `4s`. `sub_chunk_1_size` is a little-endian 32-bit unsigned integer, which would require `<I`
#
#
# | Endian | C Type     | `struct` format | python variable    |
# | -----: | :--------- | :-------------: | ------------------ |
# |    big | `char[4]`  |     `'4s'`      | `chunk_id`         |
# | little | `uint32_t` |     `'<I'`      | `chunk_size`       |
# |    big | `char[4]`  |     `'4s'`      | `format`           |
# |    big | `char[4]`  |     `'4s'`      | `sub_chunk_1_id`   |
# | little | `uint32_t` |     `'<I'`      | `sub_chunk_1_size` |
# | little | `uint16_t` |     `'<H'`      | `audio_format`     |
# | little | `uint16_t` |     `'<H'`      | `num_channels`     |
# | little | `uint32_t` |     `'<I'`      | `sample_rate`      |
# | little | `uint32_t` |     `'<I'`      | `byte_rate`        |
# | little | `uint16_t` |     `'<H'`      | `block_align`      |
# | little | `uint16_t` |     `'<H'`      | `bits_per_sample`  |
# |    big | `char[4]`  |     `'4s'`      | `sub_chunk_2_id`   |
# | little | `uint32_t` |     `'<I'`      | `sub_chunk_2_size` |
#
# Putting that all together results in the following code:

# %%
wav_file.write(struct.pack('4s', chunk_id))
wav_file.write(struct.pack('<I', chunk_size))
wav_file.write(struct.pack('4s', format))
wav_file.write(struct.pack('4s', sub_chunk_1_id))
wav_file.write(struct.pack('<I', sub_chunk_1_size))
wav_file.write(struct.pack('<H', audio_format))
wav_file.write(struct.pack('<H', num_channels))
wav_file.write(struct.pack('<I', sample_rate))
wav_file.write(struct.pack('<I', byte_rate))
wav_file.write(struct.pack('<H', block_align))
wav_file.write(struct.pack('<H', bits_per_sample))
wav_file.write(struct.pack('4s', sub_chunk_2_id))
wav_file.write(struct.pack('<I', sub_chunk_2_size))

# %% [markdown]
# If we close our file now, it _should_ be 44 bytes in size.

# %%
wav_file.close()

# %% [markdown]
# Open your file browser and locate the file. The file will be in the same directory as this notebook or your current working directory in your terminal / shell.
#
# ### PCM Audio Bit Depth
# To write the audio data, we first need to convert from floating-point values to 16-bit integers.
#
# > **Note:** Signed integer PCM data has a quirk: the maximum negative value has a greater magnitude than the maximum positive value.
#
# For 16-bit values, the total number of possible values is $2^{16}$. In signed representation, one bit is used for the sign, leaving $2^{15}$ values for each side.
#
# However, zero occupies one of these values. This results in a range of:
#
# $-2^{15}$ to $(2^{15} - 1)$
#
# In other words, there are $2^{15}$ negative values and $(2^{15} - 1)$ positive values.
#
# One simple approach is to clamp the amplitude to $2^{15} - 1$ to avoid overflow. The 16-bit format also provides a good opportunity to introduce two’s complement binary representation, depending on how deeply you want to explore the topic. In this example, we will assume the full range is equal on each side. This means we will have to clamp the positive values resulting in a distortion of the original waveform. The noise introduced is negligible in this case but provides an interesting further exercise for students.
#
# The maximum magnitude for a 16-bit signed value is considered to be $2^{15}$. Using Python’s power operator `**`, this can be written as:

# %%
max_amplitude = 2**15

# %% [markdown]
# We can generate PCM data in the desired range using a combination of the [`max`](https://docs.python.org/3/library/functions.html#max) and [`min`](https://docs.python.org/3/library/functions.html#min) functions

# %%
pcm = [max(-max_amplitude, min(max_amplitude-1, int(sample * max_amplitude))) for sample in sine_wave]

# %% [markdown]
# Breaking that down:
#
# **A**. `int(sample * max_amplitude)`: Scale samples to 2^{15}
#
# **B**. `min(max_amplitude-1,A)`: which value is smaller, **A** (`int(sample * max_amplitude)`) or $2^{15}-1$
#
# **C**. `max(-max_amplitude, B)`: which value is bigger, **B** (the output from `min`) or $-2^{15}$
#
# This should stop any accidental overflows.
#
# We can then write out this data to a file.
#
# We previously closed the file so we will have to open it again. This time we are appending data so we use the `'ab'` option:

# %%
wav_file = open(filename, 'ab')

# %% [markdown]
# The data is 16-bit signed, little endian. Remembering the tables for the struct function:
#
# | Format | Type                      |
# | :----: | ------------------------: |
# | `H`    | unsigned 16-bit integer   |
# | `h`    | signed 16-bit integer     |
# | `I`    | unsigned 32-bit integer   |
# | `s`    | byte string of characters |
#
#
# | Character | Endian   |
# | --------- | -------- |
# | `<`       | `little` |
# | `>`       | `big`    |
#
# That means our format string is `<h`

# %%
for sample in pcm:
    wav_file.write(struct.pack('<h', sample))
    
wav_file.close()

# %% [markdown]
# Lets compile that altogteher in a function called `write_wav_file` so that we can reuse it and modify it later.

# %%
def write_wav_file(audio, 
                   filename,
                   num_channels=1,
                   bits_per_sample=16,
                   sample_rate=44100,):
    
    number_of_samples = len(audio)
    chunk_id          = b'RIFF'                                             
    format            = b'WAVE'                                              
    sub_chunk_1_id    = b'fmt '                                             
    sub_chunk_1_size  = 16                                                 
    audio_format      = 1                                                  
    sub_chunk_2_id    = b'data'                                             
    byte_rate         = sample_rate * num_channels * bits_per_sample // 8     
    block_align       = num_channels * bits_per_sample // 8                   
    sub_chunk_2_size  = num_samples * num_channels * bits_per_sample // 8     
    chunk_size        = 4 + (8 + sub_chunk_1_size) + (8 + sub_chunk_2_size)

    with open(filename, 'wb') as wav_file:
        wav_file.write(struct.pack('4s', chunk_id))
        wav_file.write(struct.pack('<I', chunk_size))
        wav_file.write(struct.pack('4s', format))
        wav_file.write(struct.pack('4s', sub_chunk_1_id))
        wav_file.write(struct.pack('<I', sub_chunk_1_size))
        wav_file.write(struct.pack('<H', audio_format))
        wav_file.write(struct.pack('<H', num_channels))
        wav_file.write(struct.pack('<I', sample_rate))
        wav_file.write(struct.pack('<I', byte_rate))
        wav_file.write(struct.pack('<H', block_align))
        wav_file.write(struct.pack('<H', bits_per_sample))
        wav_file.write(struct.pack('4s', sub_chunk_2_id))
        wav_file.write(struct.pack('<I', sub_chunk_2_size))

        max_val = 2**15
        for sample in sine_wave:
            pcm_sample = int(sample * max_val)
            pcm_sample = max(-max_val, min((max_val-1), pcm_sample))  # Clamp to valid range
            wav_file.write(struct.pack('<h', pcm_sample))

# %%
write_wav_file(sine_wave, "a440hz-from-function.wav")

# %% [markdown]
# ## Reading a WAVE file
#
# A good test after creating a function to write WAVE file is to then read the data and write iit back out to another file. This should ensure that bothe read and write functions are working correctly.
#
# We have just created a file so lets try and read it

# %%
wav_file = open(filename, 'rb')

# %% [markdown]
# For reading we need to perform the reverse operation for writing. For the `struct` module this means we use th `unpack` function.
#
# `struct.unpack` always returns a tuple, even if it only has one element in it.
#
#
# We could and an index after the function like
#
# ```python
# chunk_id        = struct.unpack('4s', wav_file.read(4))[0]
# chunk_size      = struct.unpack('<I', wav_file.read(4))[0]
# format          = struct.unpack('4s', wav_file.read(4))[0]
# subchunk1_id    = struct.unpack('4s', wav_file.read(4))[0]
# subchunk1_size  = struct.unpack('<I', wav_file.read(4))[0]
# audio_format    = struct.unpack('<H', wav_file.read(2))[0]
# num_channels    = struct.unpack('<H', wav_file.read(2))[0]
# sample_rate     = struct.unpack('<I', wav_file.read(4))[0]
# byte_rate       = struct.unpack('<I', wav_file.read(4))[0]
# block_align     = struct.unpack('<H', wav_file.read(2))[0]
# bits_per_sample = struct.unpack('<H', wav_file.read(2))[0]
# subchunk2_id    = struct.unpack('4s', wav_file.read(4))[0]
# subchunk2_size  = struct.unpack('<I', wav_file.read(4))[0]
# ```
#
# With python, a cleaner method is to add a `,` after the variable, which unpacks the first (and only) element in a list.

# %%
chunk_id,        = struct.unpack('4s', wav_file.read(4))
chunk_size,      = struct.unpack('<I', wav_file.read(4))
format,          = struct.unpack('4s', wav_file.read(4))
subchunk1_id,    = struct.unpack('4s', wav_file.read(4))
subchunk1_size,  = struct.unpack('<I', wav_file.read(4))
audio_format,    = struct.unpack('<H', wav_file.read(2))
num_channels,    = struct.unpack('<H', wav_file.read(2))
sample_rate,     = struct.unpack('<I', wav_file.read(4))
byte_rate,       = struct.unpack('<I', wav_file.read(4))
block_align,     = struct.unpack('<H', wav_file.read(2))
bits_per_sample, = struct.unpack('<H', wav_file.read(2))
subchunk2_id,    = struct.unpack('4s', wav_file.read(4))
subchunk2_size,  = struct.unpack('<I', wav_file.read(4))

# %% [markdown]
# Remembering the maximum absolute value is $2^{15}$, or `2**15`.

# %%
max_amplitude = 2**15

# %% [markdown]
# `subchunk2_size` tells us the size of the audio in bytes. The number of samples is `subchunk2_size / 2` as there are 2 bytes per sample value.
#
# `wav_file.read()` will read the remainder of the file.

# %%
pcm = struct.unpack(f'<{subchunk2_size//2}h', wav_file.read())

# %% [markdown]
# These values are then scaled to floating point ±1 by dividing by out maximum value

# %%
audio = [sample / max_amplitude for sample in pcm]

# %% [markdown]
# Finally we can write the audio back out again and check that it works.

# %%
write_wav_file(audio, "a440hz-from-read-file.wav")

# %% [markdown]
# Added together our `read_wav_file` function might look like

# %%
def read_wav_file(filename):
    with open(filename, 'rb') as wav_file:                
        chunk_id,        = struct.unpack('4s', wav_file.read(4))
        chunk_size,      = struct.unpack('<I', wav_file.read(4))
        format,          = struct.unpack('4s', wav_file.read(4))
        subchunk1_id,    = struct.unpack('4s', wav_file.read(4))
        subchunk1_size,  = struct.unpack('<I', wav_file.read(4))
        audio_format,    = struct.unpack('<H', wav_file.read(2))
        num_channels,    = struct.unpack('<H', wav_file.read(2))
        sample_rate,     = struct.unpack('<I', wav_file.read(4))
        byte_rate,       = struct.unpack('<I', wav_file.read(4))
        block_align,     = struct.unpack('<H', wav_file.read(2))
        bits_per_sample, = struct.unpack('<H', wav_file.read(2))
        subchunk2_id,    = struct.unpack('4s', wav_file.read(4))
        subchunk2_size,  = struct.unpack('<I', wav_file.read(4))
            
        number_of_frames = subchunk2_size // (bits_per_sample // 8)

        max_amplitude = 2**15
        pcm = struct.unpack(f'<{subchunk2_size//2}h', wav_file.read())
        audio = [sample / max_amplitude for sample in pcm]

    return audio

# %% [markdown]
# ## Ideas for expansion
#
# So far, we have learned how to successfully write a monophonic, 44.1 kHz, 16-bit WAVE file. There are many ways to build on these simple functions that can provide interesting challenges for students.
#
# Some ideas for extension include:
#
# - **Return metadata:** Modify the read function so that it returns not only the audio data, but also metadata (e.g. sample rate, bit depth, number of channels). This could be implemented using a dictionary, or by restructuring the code into a class.
#
# - **Correct amplitude scaling:** Recall that we used a magnitude of $2^{15}$. The maximum positive amplitude should actually be $2^{15} - 1$. Add logic to correctly scale values when converting to 16-bit integers.
#
# - **Alternative bit depths:** Extend the implementation to support 8-bit, 24-bit, and 32-bit integer audio. You could also try IEEE 32-bit floating-point format ( where `audio_format = 0x0003`). A useful exercise is to test compatibility across different digital audio workstations (DAWs) and media players — do all formats behave consistently?
#
# - **Stereo and multichannel audio:** Stereo (and more generally, multichannel PCM) audio is stored in an interleaved format. Add support for multiple channels and implement checks on input data shape. This introduces useful challenges around validation and user feedback, and works well as part of a larger group project.
#
#
# Now that the student is comfortable creating audio files from raw data, these principles can be integrated into a broader lesson plan focused on generating audio, algorithmic composition, or creative signal processing.

# %% [markdown]
# ## Using the `wave` Module
#
# The [`wave` module](https://docs.python.org/3/library/wave.html) is one of pythons oldest original standard liraries meaning it can be considered universal and is guarenteed to be available in any python install.
#
# The wave library provides some handy functions to deal with parsing the header of a wav file so you don't have to do the work.
#
# Begin first by importing `wave`:

# %%
import wave

# %% [markdown]
# as always, we import some functions and variables from the math library

# %%
from math import sin, pi

# %% [markdown]
# here we can create our sine wav to be written to a file

# %%
fs = 44100.0   # Sampling Rate 
f0 = 440.0     # Fundamental frequency
duration = 1.0 # in seconds

delta = 2.0 * pi * f0 / fs # how much does the phase change between samples

sine_wave = [sin(delta * i) for i in range(int(duration*fs))]

# %% [markdown]
# The `wave` module expects audio data to be in a byte format. We need to import the `struct` module which provides the ability to transform from one data type to another.
#
# We currently have a list of sample values and before we can write them to a file we need to turn them into a byte-string.
#
# This is typical data wrangling and will be an expected stage whenever writing data to a file.
#
# It can be a little daunting for it to be one of the first things to introduce to students. Therefore, it is one of the benefits to abstracting the process away in a library. At first they can use the library you provide, but after a while you can invite them to open up the file and explore a little further.

# %%
import struct

# %% [markdown]
# For explanation on the bit depth and scaling the audio see the [PCM-Audio-Bit-Depth section above](#PCM-Audio-Bit-Depth)
#
# This time we will take the more simplistic approach and scale to $2^{15} - 1$

# %%
bit_depth = 16
max_amplitude = (2 ** (bit_depth - 1)) - 1
num_samples = len(sine_wave)

# %% [markdown]
# To gather the byte data together we need to scale the current audio to the `max_amplitude` and then pack it into a byte string.
#
# The list `[int(sample * max_amplitude) for sample in sine_wave]` comprehension creates a list of scaled sample values.
#
# `num_samples` can be passed to `struct.pack` using an f string `f'<{num_samples}h'`
#
# Finally, the [`*` operator](https://docs.python.org/3/reference/expressions.html#expression-lists) unpacks the list so that it can be used as the input to `struct.pack`

# %%
byte_data = struct.pack(f'<{num_samples}h', *[int(sample * max_amplitude) for sample in sine_wave])

# %% [markdown]
# We open the file with [`wave.open`](https://docs.python.org/3/library/wave.html#wave.open)

# %%
filename = 'a440Hz-wave-module.wav'
wave_file = wave.open(filename, 'wb')

# %% [markdown]
# Before we can write the audio data to a file there are a couple of pieces of metadata to confiugure, namely
#
# - number of channels
# - byte depth
# - sample rate

# %%
wave_file.setnchannels(1)  # mono
wave_file.setsampwidth(bit_depth // 8)  # 16-bit depth i.e. 2 bytes
wave_file.setframerate(int(fs))

# %% [markdown]
# after setting those we can write the byte data

# %%
wave_file.writeframesraw(byte_data)

# %%
wave_file.close()

# %% [markdown]
# # Reading a wav file
#
# Reading is a lot more simplistic than writing as a lot of decisions have been made for you.
#
# In general, to read a wav file you should expect to deal with three elements
#
# 1. opening a file object in read mode
# 2. reading byte data
# 3. transforming byte data into floating point format
#
# For python it will be easiest to keep the audio sample format to a list of float type numbers.
# This is closest to what you will find in other programming languages.
#
# This assumes you are enforcing wav files with
#
# - 1 channel (mono)
# - 16-bit depth

# %%
import wave
import struct

wave_file = wave.open(filename, 'rb')
p = wave_file.getparams()
frames = wave_file.readframes(p.nframes)
audio_samples = [sample[0] / max_amplitude for sample in struct.iter_unpack('<h',frames)]

# %% [markdown]
# The `struct` library's `unpack` functions always return a tuple, even if they are only 1 element long, the sort of arbitrary decision that can snipe some students into paralysis as they try to navigate. Another good reason to remove this kind of operation from view.

# %% [markdown]
# ## An Example Library
#
# Below is an example of a simple library you could provide to students.
#
# You can modify it depending on the focus of your lessons. For example:
# - If the lesson is about DSP, now might not be the time to penalize students for getting the file extension wrong.
# - If the focus _is_ holistic programming skills—such as error handling—consider changing the `if not filename.endswith('.wav'):` check to raise a helpful error instead.
#
# The library is intentionally limited, and that is part of the point. It should only be a handful of lines; in this example, under 30 lines.
#
# It strikes a middle ground by enforcing essential parameters like sample rate and bit depth, without overcomplicating the interface.
#
# Don’t hesitate to admit if you designed the library incorrectly at first—if students consistently get stuck at the same point, you can adjust it quickly and demonstrate agile development in practice.
#
# To import the library, students simply type:
#
# ```py
# from wav_library import *
# ```
#
# they then will have access to the `write_wav_file` and `read_wav_file` functions.

# %%
# wav_library
#
# To import, all students should have to type is 
#
# ```py
# from wav_library import *
# ```
#
# After which they will have access to the `write_wav_file` and `read_wav_file` functions
#
import struct
import wave
from math import sin, pi

def write_wav_file(float_data, filename, nchannels=1, bit_depth=16, sample_rate=44100):
    
    normalisation = 1 / max([abs(x) for x in float_data])
    
    float_data = [sample * normalisation for sample in float_data]
    
    if not filename.endswith('.wav'):
        filename += '.wav'
        
    with wave.open(filename, 'wb') as wave_file:
        wave_file.setnchannels(nchannels)
        wave_file.setsampwidth(bit_depth // 8)
        wave_file.setframerate(sample_rate)
                
        max_amplitude = (2 ** (bit_depth - 1) - 1)
        byte_data = b''.join([struct.pack('<h', int(sample * max_amplitude)) for sample in float_data])
        
        wave_file.writeframesraw(byte_data)

def read_wav_file(filename):

    if not filename.endswith('.wav'):
        filename += '.wav'
        
    with wave.open(filename, 'rb') as wave_file:
        p = wave_file.getparams()
        frames = wave_file.readframes(p.nframes)
        audio_samples = [sample[0] / max_amplitude for sample in struct.iter_unpack('<h',frames)]
        return audio_samples

# %% [markdown]
# ### Limitations
#
# There are several drawbacks and potential stumbling blocks that are worth noting:
#
# - **File naming:** Guessing or hardcoding file names can lead to confusion later.
# - **Mono-only support:** This approach does not support stereo or multichannel audio.
# - **Language portability:** The implementation relies heavily on Python list comprehensions, which are not directly transferable to languages like C that are commonly used in audio programming. Using standard `for` loops may improve portability.
# - **Messy returns:** The read function returns many separate variables. While an object-oriented approach could simplify this, it introduces additional complexity elsewhere.
# - **Rigid parameters:** This approach assumes fixed parameters (e.g., sample rate, bit depth) which may not suit students using their own audio data.
# - **Automatic normalization:** Audio is always normalized using `normalisation = 1.0 / max(abs(float_data))`, which may not be desired in all contexts.
#
# All of which can be presented an exercise for the student to address.
